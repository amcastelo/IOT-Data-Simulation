# %%
from web3 import Web3

# Connect to local Ganache blockchain
ganache_url = "http://127.0.0.1:7545"
web3 = Web3(Web3.HTTPProvider(ganache_url))


if web3.is_connected():
    print("✅ Connected to Ganache successfully!")
else:
    print("❌ Connection failed. Ensure Ganache is running.")

# Replace with actual contract address from Remix
contract_address = "0x8a942682Ad8DD2D8797a33C1082B074a25C77367"


# Paste the ABI from Remix
abi = [
    {
        "inputs": [],
        "stateMutability": "nonpayable",
        "type": "constructor"
    },
    {
        "anonymous": False,
        "inputs": [
            {
                "indexed": False,
                "internalType": "uint256",
                "name": "timestamp",
                "type": "uint256"
            },
            {
                "indexed": False,
                "internalType": "string",
                "name": "orderId",
                "type": "string"
            },
            {
                "indexed": False,
                "internalType": "string",
                "name": "packageId",
                "type": "string"
            },
            {
                "indexed": False,
                "internalType": "string",
                "name": "status",
                "type": "string"
            },
            {
                "indexed": False,
                "internalType": "string",
                "name": "location",
                "type": "string"
            },
            {
                "indexed": False,
                "internalType": "string",
                "name": "temperature",
                "type": "string"
            },
            {
                "indexed": False,
                "internalType": "string",
                "name": "humidity",
                "type": "string"
            },
            {
                "indexed": False,
                "internalType": "string",
                "name": "gpsLatitude",
                "type": "string"
            },
            {
                "indexed": False,
                "internalType": "string",
                "name": "gpsLongitude",
                "type": "string"
            },
            {
                "indexed": False,
                "internalType": "string",
                "name": "driverId",
                "type": "string"
            },
            {
                "indexed": False,
                "internalType": "string",
                "name": "driverName",
                "type": "string"
            },
            {
                "indexed": False,
                "internalType": "string",
                "name": "licensePlate",
                "type": "string"
            }
        ],
        "name": "PackageUpdateLogged",
        "type": "event"
    },
    {
        "inputs": [],
        "name": "MAX_ENTRIES",
        "outputs": [
            {
                "internalType": "uint256",
                "name": "",
                "type": "uint256"
            }
        ],
        "stateMutability": "view",
        "type": "function"
    },
    {
        "inputs": [],
        "name": "getTotalUpdateRecords",
        "outputs": [
            {
                "internalType": "uint256",
                "name": "",
                "type": "uint256"
            }
        ],
        "stateMutability": "view",
        "type": "function"
    },
    {
        "inputs": [
            {
                "internalType": "uint256",
                "name": "index",
                "type": "uint256"
            }
        ],
        "name": "getUpdateRecord",
        "outputs": [
            {
                "internalType": "uint256",
                "name": "",
                "type": "uint256"
            },
            {
                "internalType": "string",
                "name": "",
                "type": "string"
            },
            {
                "internalType": "string",
                "name": "",
                "type": "string"
            },
            {
                "internalType": "string",
                "name": "",
                "type": "string"
            },
            {
                "internalType": "string",
                "name": "",
                "type": "string"
            },
            {
                "internalType": "string",
                "name": "",
                "type": "string"
            },
            {
                "internalType": "string",
                "name": "",
                "type": "string"
            },
            {
                "internalType": "string",
                "name": "",
                "type": "string"
            },
            {
                "internalType": "string",
                "name": "",
                "type": "string"
            }
        ],
        "stateMutability": "view",
        "type": "function"
    },
    {
        "inputs": [],
        "name": "owner",
        "outputs": [
            {
                "internalType": "address",
                "name": "",
                "type": "address"
            }
        ],
        "stateMutability": "view",
        "type": "function"
    },
    {
        "inputs": [
            {
                "internalType": "string",
                "name": "_orderId",
                "type": "string"
            },
            {
                "internalType": "string",
                "name": "_packageId",
                "type": "string"
            },
            {
                "internalType": "string",
                "name": "_status",
                "type": "string"
            },
            {
                "internalType": "string",
                "name": "_location",
                "type": "string"
            },
            {
                "internalType": "string",
                "name": "_temperature",
                "type": "string"
            },
            {
                "internalType": "string",
                "name": "_humidity",
                "type": "string"
            },
            {
                "internalType": "string",
                "name": "_gpsLatitude",
                "type": "string"
            },
            {
                "internalType": "string",
                "name": "_gpsLongitude",
                "type": "string"
            },
            {
                "internalType": "string",
                "name": "_driverId",
                "type": "string"
            },
            {
                "internalType": "string",
                "name": "_driverName",
                "type": "string"
            },
            {
                "internalType": "string",
                "name": "_licensePlate",
                "type": "string"
            }
        ],
        "name": "storeUpdateRecord",
        "outputs": [],
        "stateMutability": "nonpayable",
        "type": "function"
    },
    {
        "inputs": [
            {
                "internalType": "uint256",
                "name": "",
                "type": "uint256"
            }
        ],
        "name": "updateRecords",
        "outputs": [
            {
                "internalType": "uint256",
                "name": "timestamp",
                "type": "uint256"
            },
            {
                "internalType": "string",
                "name": "orderId",
                "type": "string"
            },
            {
                "internalType": "string",
                "name": "packageId",
                "type": "string"
            },
            {
                "internalType": "string",
                "name": "status",
                "type": "string"
            },
            {
                "internalType": "string",
                "name": "location",
                "type": "string"
            },
            {
                "internalType": "string",
                "name": "temperature",
                "type": "string"
            },
            {
                "internalType": "string",
                "name": "humidity",
                "type": "string"
            },
            {
                "internalType": "string",
                "name": "gpsLatitude",
                "type": "string"
            },
            {
                "internalType": "string",
                "name": "gpsLongitude",
                "type": "string"
            }
        ],
        "stateMutability": "view",
        "type": "function"
    }
]



# Load the smart contract
contract = web3.eth.contract(address=contract_address, abi=abi)


# Set the default sender address (first account from Ganache)
web3.eth.default_account = web3.eth.accounts[0]


print(f"✅ Connected to Smart Contract at {contract_address}")
# Out:
# ✅ Connected to Ganache successfully!
# ✅ Connected to Smart Contract at 0x8a942682Ad8DD2D8797a33C1082B074a25C77367

# %%
# Store a dummy IoT update record to test blockchain transaction
txn = contract.functions.storeUpdateRecord(
    "ORDER001",        # _orderId
    "PKG001",          # _packageId
    "In Transit",      # _status
    "Warehouse A",     # _location
    "22.5°C",          # _temperature
    "60%",             # _humidity
    "14.5995",         # _gpsLatitude
    "120.9842",        # _gpsLongitude
    "DRV123",          # _driverId
    "Juan Dela Cruz",  # _driverName
    "ABC1234"          # _licensePlate
).transact({
    'from': web3.eth.default_account,
    'gas': 1000000
})

# Wait for the transaction to be mined
receipt = web3.eth.wait_for_transaction_receipt(txn)
print("✅ Dummy IoT data stored on blockchain!")
# Out:
# ✅ Dummy IoT data stored on blockchain!

# %%
# ✅ Retrieve total number of stored records
total_records = contract.functions.getTotalUpdateRecords().call()
print(f"✅ Total Records on Blockchain: {total_records}")

# ✅ Fetch and display the first stored record (index 0)
if total_records > 0:
    record = contract.functions.getUpdateRecord(0).call()
    print("✅ First Stored Record:")
    print(f"Timestamp: {record[0]}")
    print(f"Order ID: {record[1]}")
    print(f"Package ID: {record[2]}")
    print(f"Status: {record[3]}")
    print(f"Location: {record[4]}")
    print(f"Temperature: {record[5]}")
    print(f"Humidity: {record[6]}")
    print(f"GPS Latitude: {record[7]}")
    print(f"GPS Longitude: {record[8]}")

else:
    print("⚠️ No records found.")
# Out:
# ✅ Total Records on Blockchain: 1
# ✅ First Stored Record:
# Timestamp: 1747824949
# Order ID: ORDER001
# Package ID: PKG001
# Status: In Transit
# Location: Warehouse A
# Temperature: 22.5°C
# Humidity: 60%
# GPS Latitude: 14.5995
# GPS Longitude: 120.9842
